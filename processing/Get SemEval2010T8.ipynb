# %% [markdown]
# * TRAIN JSON: 8000 Examples
# * TEST JSON: 2717 Examples (ID 8001 to 10717)

# %%
data_dir = r"D:\59 Github Projects\0014 RelExtraction\RIFRE\datasets\data\new_semeval"
all_filenames = ['train.json', 'test.json']

# %%
import json
import os
import csv
import pandas as pd
import numpy as np


def open_json(json_file_path, data_format=list):
    if data_format==dict or data_format=='dict':
        with open(json_file_path) as json_file:
            data = json.load(json_file)
    elif data_format==list or data_format=='list':
        data = []
        for line in open(json_file_path, encoding='utf-8'):
            data.append(json.loads(line))
    elif data_format==pd.DataFrame or data_format=='pd.DataFrame':
        data = pd.read_json(json_file_path, orient="records", lines=True)
    else:
        raise NotImplementedError
    return data

file = all_filenames[1]
fn = os.path.join(data_dir, file)
# fn = r"D:\59 Github Projects\0014 RelExtraction\RIFRE\datasets\data\new_semeval\train.json"
original_data = open_json(fn, data_format=dict)
original_data
# Out:
# [{'id': '8001',
#   'tokens': ['The',
#    'most',
#    'common',
#    'audits',
#    'were',
#    'about',
#    'waste',
#    'and',
#    'recycling',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[3, 4], [6, 7]]},
#  {'id': '8002',
#   'tokens': ['The', 'company', 'fabricates', 'plastic', 'chairs', '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[4, 5], [1, 2]]},
#  {'id': '8003',
#   'tokens': ['The',
#    'school',
#    'master',
#    'teaches',
#    'the',
#    'lesson',
#    'with',
#    'a',
#    'stick',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[8, 9], [2, 3]]},
#  {'id': '8004',
#   'tokens': ['The',
#    'suspect',
#    'dumped',
#    'the',
#    'dead',
#    'body',
#    'into',
#    'a',
#    'local',
#    'reservoir',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[5, 6], [9, 10]]},
#  {'id': '8005',
#   'tokens': ['Avian',
#    'influenza',
#    'is',
#    'an',
#    'infectious',
#    'disease',
#    'of',
#    'birds',
#    'caused',
#    'by',
#    'type',
#    'A',
#    'strains',
#    'of',
#    'the',
#    'influenza',
#    'virus',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[16, 17], [1, 2]]},
#  {'id': '8006',
#   'tokens': ['The',
#    'ear',
#    'of',
#    'the',
#    'African',
#    'elephant',
#    'is',
#    'significantly',
#    'larger--measuring',
#    '183',
#    'cm',
#    'by',
#    '114',
#    'cm',
#    'in',
#    'the',
#    'bush',
#    'elephant',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[1, 2], [5, 6]]},
#  {'id': '8007',
#   'tokens': ['A',
#    'child',
#    'is',
#    'told',
#    'a',
#    'lie',
#    'for',
#    'several',
#    'years',
#    'by',
#    'their',
#    'parents',
#    'before',
#    'he/she',
#    'realizes',
#    'that',
#    'a',
#    'Santa',
#    'Claus',
#    'does',
#    'not',
#    'exist',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[5, 6], [11, 12]]},
#  {'id': '8008',
#   'tokens': ['Skype',
#    ',',
#    'a',
#    'free',
#    'software',
#    ',',
#    'allows',
#    'a',
#    'hookup',
#    'of',
#    'multiple',
#    'computer',
#    'users',
#    'to',
#    'join',
#    'in',
#    'an',
#    'online',
#    'conference',
#    'call',
#    'without',
#    'incurring',
#    'any',
#    'telephone',
#    'costs',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[12, 13], [8, 9]]},
#  {'id': '8009',
#   'tokens': ['The',
#    'disgusting',
#    'scene',
#    'was',
#    'retaliation',
#    'against',
#    'her',
#    'brother',
#    'Philip',
#    'who',
#    'rents',
#    'the',
#    'room',
#    'inside',
#    'this',
#    'apartment',
#    'house',
#    'on',
#    'Lombard',
#    'street',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[12, 13], [16, 17]]},
#  {'id': '8010',
#   'tokens': ['This',
#    'thesis',
#    'defines',
#    'the',
#    'clinical',
#    'characteristics',
#    'of',
#    'amyloid',
#    'disease',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [4, 6]]},
#  {'id': '8011',
#   'tokens': ['Ten',
#    'million',
#    'quake',
#    'survivors',
#    'moved',
#    'into',
#    'makeshift',
#    'houses',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[3, 4], [7, 8]]},
#  {'id': '8012',
#   'tokens': ['On',
#    'a',
#    'friend',
#    "'",
#    's',
#    'advice',
#    ',',
#    'I',
#    'purchased',
#    'a',
#    'sauerkraut',
#    'and',
#    'kimchi',
#    'maker',
#    'here',
#    'and',
#    'it',
#    'is',
#    'just',
#    'fabulous',
#    '(and',
#    'cheap',
#    'too)',
#    '.'],
#   'label': 'Other',
#   'entities': [[13, 14], [12, 13]]},
#  {'id': '8013',
#   'tokens': ['NASA',
#    'Kepler',
#    'mission',
#    'sends',
#    'names',
#    'into',
#    'space',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[4, 5], [6, 7]]},
#  {'id': '8014',
#   'tokens': ['As',
#    'a',
#    'landscape',
#    'company',
#    'in',
#    'Atlanta',
#    ',',
#    'we',
#    'know',
#    'which',
#    'plants',
#    'thrive',
#    'in',
#    'this',
#    'planting',
#    'zone',
#    'and',
#    'know',
#    'the',
#    'optimum',
#    'landscaping',
#    'designs',
#    'for',
#    'local',
#    'yards',
#    'and',
#    'business',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[2, 3], [3, 4]]},
#  {'id': '8015',
#   'tokens': ['As',
#    'I',
#    'was',
#    'contemplating',
#    'if',
#    'I',
#    'had',
#    'a',
#    'favorite',
#    'in',
#    'the',
#    'pink',
#    'category',
#    ',',
#    'a',
#    'gift',
#    'arrived',
#    'from',
#    'a',
#    'sweet',
#    'friend',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[15, 16], [20, 21]]},
#  {'id': '8016',
#   'tokens': ['The',
#    'male',
#    'took',
#    'over',
#    'the',
#    'entire',
#    'care',
#    'of',
#    'the',
#    'young',
#    'that',
#    'had',
#    'left',
#    'the',
#    'nest',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[9, 10], [14, 15]]},
#  {'id': '8017',
#   'tokens': ['The',
#    'famous',
#    'actress',
#    'arrived',
#    'at',
#    'the',
#    'airport',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[2, 3], [6, 7]]},
#  {'id': '8018',
#   'tokens': ['An',
#    'FTP',
#    'server',
#    'is',
#    'an',
#    'inexpensive',
#    'and',
#    'relatively',
#    'simple',
#    'to',
#    'operate',
#    'tool',
#    'that',
#    'works',
#    'great',
#    'for',
#    'filesharing',
#    'over',
#    'the',
#    'internet',
#    '.'],
#   'label': 'Other',
#   'entities': [[19, 20], [16, 17]]},
#  {'id': '8019',
#   'tokens': ['Beneath',
#    'this',
#    'invocation',
#    'there',
#    'is',
#    'a',
#    'zoo',
#    'of',
#    'fearsome',
#    'beasts',
#    ',',
#    'including',
#    'several',
#    'man-eaters',
#    ',',
#    'as',
#    'well',
#    'as',
#    'sphinxes',
#    'with',
#    'lions',
#    "'",
#    'bodies',
#    'and',
#    'human',
#    'heads',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[9, 10], [6, 7]]},
#  {'id': '8020',
#   'tokens': ['The',
#    'song',
#    'was',
#    'composed',
#    'for',
#    'a',
#    'famous',
#    'Brazilian',
#    'musician',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[1, 2], [8, 9]]},
#  {'id': '8021',
#   'tokens': ['This',
#    'outline',
#    'focuses',
#    'on',
#    'spirituality',
#    ',',
#    'esotericism',
#    ',',
#    'mysticism',
#    ',',
#    'religion',
#    'and/or',
#    'parapsychology',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [4, 5]]},
#  {'id': '8022',
#   'tokens': ['The',
#    'bomb',
#    'was',
#    'in',
#    'a',
#    'suitcase',
#    'loaded',
#    'in',
#    'Frankfurt',
#    'and',
#    'transferred',
#    'to',
#    'the',
#    'doomed',
#    'Boeing',
#    '747',
#    'in',
#    'London',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[1, 2], [5, 6]]},
#  {'id': '8023',
#   'tokens': ['I',
#    'spent',
#    'a',
#    'year',
#    'working',
#    'for',
#    'a',
#    'software',
#    'company',
#    'to',
#    'pay',
#    'off',
#    'my',
#    'college',
#    'loans',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[7, 8], [8, 9]]},
#  {'id': '8024',
#   'tokens': ['The',
#    'captain',
#    'and',
#    'the',
#    'crew',
#    'of',
#    'the',
#    'Steve',
#    'Irwin',
#    'are',
#    'grateful',
#    'for',
#    'the',
#    'support',
#    'of',
#    'the',
#    'City',
#    'of',
#    'Fremantle',
#    'and',
#    'Mayor',
#    'Brad',
#    'Pettitt',
#    'for',
#    'hosting',
#    'the',
#    'event',
#    '.'],
#   'label': 'Other',
#   'entities': [[4, 5], [1, 2]]},
#  {'id': '8025',
#   'tokens': ['Organic',
#    'sesame',
#    'oil',
#    'has',
#    'an',
#    'anti-bacterial',
#    'and',
#    'anti',
#    'imflammatory',
#    'effect',
#    '.'],
#   'label': 'Entity-Origin(e2,e1)',
#   'entities': [[2, 3], [1, 2]]},
#  {'id': '8026',
#   'tokens': ['Mileson',
#    'has',
#    'sold',
#    'his',
#    'humble',
#    'abode',
#    'to',
#    'a',
#    'housing',
#    'developer',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[8, 9], [9, 10]]},
#  {'id': '8027',
#   'tokens': ['The',
#    'same',
#    'effect',
#    'is',
#    'achieved',
#    'the',
#    'traditional',
#    'way',
#    ',',
#    'with',
#    'a',
#    'team',
#    'of',
#    'workers',
#    'like',
#    'Keebler',
#    'elves',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[7, 8], [2, 3]]},
#  {'id': '8028',
#   'tokens': ['He',
#    'has',
#    'built',
#    'a',
#    'formidable',
#    'reputation',
#    'writing',
#    'powerful',
#    'dramas',
#    'for',
#    'the',
#    'stage',
#    'and',
#    'screen',
#    ',',
#    'based',
#    'on',
#    'real',
#    'events',
#    'or',
#    'socially',
#    'vital',
#    'issues',
#    '.'],
#   'label': 'Other',
#   'entities': [[17, 19], [8, 9]]},
#  {'id': '8029',
#   'tokens': ['He',
#    'produces',
#    'drawings',
#    'and',
#    'videos',
#    'that',
#    'have',
#    'been',
#    'shown',
#    'in',
#    'museums',
#    'in',
#    'Europe',
#    'and',
#    'America',
#    '.'],
#   'label': 'Other',
#   'entities': [[10, 11], [2, 3]]},
#  {'id': '8030',
#   'tokens': ['Therefore',
#    ',',
#    'nowadays',
#    'China',
#    'is',
#    'the',
#    'complex',
#    'mixture',
#    'of',
#    'different',
#    'cultures',
#    'from',
#    'various',
#    'epochs',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[10, 11], [13, 14]]},
#  {'id': '8031',
#   'tokens': ['Of',
#    'the',
#    'hundreds',
#    'of',
#    'strains',
#    'of',
#    'avian',
#    'influenza',
#    'A',
#    'viruses',
#    ',',
#    'only',
#    'four',
#    'have',
#    'caused',
#    'human',
#    'infections',
#    ':',
#    'H5N1',
#    ',',
#    'H7N3',
#    ',',
#    'H7N7',
#    ',',
#    'and',
#    'H9N2',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[9, 10], [16, 17]]},
#  {'id': '8032',
#   'tokens': ['Many',
#    'of',
#    'his',
#    'literary',
#    'pieces',
#    'narrate',
#    'and',
#    'mention',
#    'stories',
#    'that',
#    'took',
#    'place',
#    'in',
#    'Lipa',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[4, 5], [8, 9]]},
#  {'id': '8033',
#   'tokens': ['When',
#    'I',
#    "'",
#    'm',
#    'walking',
#    'alone',
#    ',',
#    'I',
#    'count',
#    'the',
#    'steps',
#    'of',
#    'the',
#    'stairs',
#    ',',
#    'and',
#    'I',
#    'also',
#    'guess',
#    'approximately',
#    'how',
#    'many',
#    'steps',
#    'are',
#    'left',
#    'till',
#    'I',
#    'reach',
#    'the',
#    'next',
#    'street',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[10, 11], [13, 14]]},
#  {'id': '8034',
#   'tokens': ['Essentially',
#    ',',
#    'the',
#    'blisters',
#    'that',
#    'appear',
#    'in',
#    'the',
#    'mouth',
#    'are',
#    'caused',
#    'by',
#    'the',
#    'herpes',
#    'simplex',
#    'virus',
#    'type',
#    '1',
#    ',',
#    'HSV-1',
#    'for',
#    'short',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[3, 4], [13, 16]]},
#  {'id': '8035',
#   'tokens': ['The',
#    'man',
#    'at',
#    'the',
#    'helm',
#    'was',
#    'watching',
#    'the',
#    'luff',
#    'of',
#    'the',
#    'sail',
#    'and',
#    'whistling',
#    'away',
#    'gently',
#    'to',
#    'himself',
#    ',',
#    'and',
#    'that',
#    'was',
#    'the',
#    'only',
#    'sound',
#    'excepting',
#    'the',
#    'swish',
#    'of',
#    'the',
#    'sea',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[8, 9], [11, 12]]},
#  {'id': '8036',
#   'tokens': ['Still',
#    'further',
#    ',',
#    'the',
#    'circuit',
#    'comprises',
#    'a',
#    'digital',
#    'adder',
#    'and',
#    'an',
#    'analog-to-digital',
#    'converter',
#    'with',
#    'an',
#    'analog',
#    'input',
#    'connected',
#    'to',
#    'the',
#    'output',
#    'of',
#    'the',
#    'operational',
#    'amplifier',
#    'and',
#    'a',
#    'digital',
#    'output',
#    'connected',
#    'to',
#    'a',
#    'first',
#    'input',
#    'of',
#    'the',
#    'digital',
#    'adder',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[12, 13], [4, 5]]},
#  {'id': '8037',
#   'tokens': ['Dolf',
#    'Oehler',
#    ',',
#    'a',
#    'leader',
#    'in',
#    'the',
#    'leftist',
#    'camp',
#    'of',
#    'Heine',
#    'champions',
#    'since',
#    'the',
#    '1970s',
#    ',',
#    'gathered',
#    'a',
#    'group',
#    'of',
#    'likeminded',
#    'critics',
#    'for',
#    'this',
#    'symposium',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[11, 12], [8, 9]]},
#  {'id': '8038',
#   'tokens': ['The',
#    'cartridge',
#    'was',
#    'marked',
#    'as',
#    'empty',
#    ',',
#    'even',
#    'with',
#    'ink',
#    'in',
#    'both',
#    'chambers',
#    '.'],
#   'label': 'Content-Container(e2,e1)',
#   'entities': [[9, 10], [1, 2]]},
#  {'id': '8039',
#   'tokens': ['A',
#    'pod',
#    'of',
#    'sperm',
#    'whales',
#    'was',
#    'beached',
#    'on',
#    'Italy',
#    "'",
#    's',
#    'southern',
#    'coast',
#    'and',
#    'at',
#    'least',
#    'five',
#    'died',
#    'in',
#    'what',
#    'experts',
#    'said',
#    'was',
#    'a',
#    'rare',
#    'and',
#    'puzzling',
#    'mass',
#    'beaching',
#    'for',
#    'such',
#    'a',
#    'large',
#    'species',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[4, 5], [1, 2]]},
#  {'id': '8040',
#   'tokens': ['Roundworms',
#    'or',
#    'ascarids',
#    'are',
#    'caused',
#    'by',
#    'an',
#    'intestinal',
#    'parasite',
#    'called',
#    'Toxocara',
#    'canis',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[0, 1], [8, 9]]},
#  {'id': '8041',
#   'tokens': ['The',
#    'subject',
#    'of',
#    '"imply"',
#    'is',
#    'the',
#    'source',
#    'of',
#    'an',
#    'implication',
#    'while',
#    'the',
#    'subject',
#    'of',
#    '"infer"',
#    'is',
#    'the',
#    'recipient',
#    'of',
#    'an',
#    'implication',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[1, 2], [9, 10]]},
#  {'id': '8042',
#   'tokens': ['My', 'cat', 'has', 'a', 'problem', 'with', 'his', 'paw', '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[7, 8], [1, 2]]},
#  {'id': '8043',
#   'tokens': ['The',
#    'treaty',
#    'establishes',
#    'a',
#    'double',
#    'majority',
#    'rule',
#    'for',
#    'Council',
#    'decisions',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[1, 2], [6, 7]]},
#  {'id': '8044',
#   'tokens': ['The',
#    'accident',
#    'has',
#    'spread',
#    'oil',
#    'into',
#    'the',
#    'ocean',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[4, 5], [7, 8]]},
#  {'id': '8045',
#   'tokens': ['A',
#    'tidal',
#    'wave',
#    'of',
#    'talent',
#    'has',
#    'emanated',
#    'from',
#    'this',
#    'lush',
#    'village',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[4, 5], [10, 11]]},
#  {'id': '8046',
#   'tokens': ['These',
#    'coins',
#    'are',
#    'enclosed',
#    'in',
#    'a',
#    'clear',
#    'hard',
#    'plastic',
#    'case',
#    'with',
#    'a',
#    'blue',
#    'background',
#    'that',
#    'is',
#    'packaged',
#    'in',
#    'a',
#    'blue',
#    'box',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[1, 2], [8, 10]]},
#  {'id': '8047',
#   'tokens': ['By',
#    'dividing',
#    'the',
#    'space',
#    'in',
#    'a',
#    'kitchen',
#    'drawer',
#    'where',
#    'you',
#    'keep',
#    'all',
#    'your',
#    'cooking',
#    'utensils',
#    ',',
#    'you',
#    'grouped',
#    'items',
#    'by',
#    'size',
#    'or',
#    'purpose',
#    '.'],
#   'label': 'Other',
#   'entities': [[7, 8], [3, 4]]},
#  {'id': '8048',
#   'tokens': ['Then',
#    ',',
#    'the',
#    'target',
#    'PET',
#    'bottle',
#    'was',
#    'put',
#    'inside',
#    'of',
#    'a',
#    'metal',
#    'container',
#    ',',
#    'which',
#    'was',
#    'grounded',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[5, 6], [12, 13]]},
#  {'id': '8049',
#   'tokens': ['News',
#    'programs',
#    'commented',
#    'on',
#    'the',
#    'violence',
#    'from',
#    'the',
#    'game',
#    'and',
#    'expressed',
#    'worries',
#    'on',
#    'how',
#    'it',
#    'would',
#    'affect',
#    'the',
#    'players',
#    "'",
#    'personalities',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[0, 2], [5, 6]]},
#  {'id': '8050',
#   'tokens': ['The',
#    'narrative',
#    'comprises',
#    'the',
#    'interplay',
#    'of',
#    'two',
#    'themes',
#    'that',
#    'are',
#    'woven',
#    'together',
#    'as',
#    'it',
#    'criss-crosses',
#    'back',
#    'and',
#    'forth',
#    'between',
#    'the',
#    'life',
#    'of',
#    'nineteen',
#    'year',
#    'old',
#    'Greg',
#    'Kowalski',
#    "'",
#    's',
#    'desire',
#    'to',
#    'become',
#    'a',
#    'firefighter',
#    'and',
#    'his',
#    'heart-rending',
#    'life',
#    'growing',
#    'up',
#    'in',
#    'Saginaw',
#    'Michigan',
#    'where',
#    'he',
#    'had',
#    'to',
#    'endure',
#    'the',
#    'physical',
#    'and',
#    'verbal',
#    'abuse',
#    'handed',
#    'out',
#    'by',
#    'his',
#    'appalling',
#    'father',
#    '.'],
#   'label': 'Other',
#   'entities': [[4, 5], [1, 2]]},
#  {'id': '8051',
#   'tokens': ['As',
#    'Vinay',
#    'collapsed',
#    'in',
#    'pain',
#    ',',
#    'the',
#    'villagers',
#    'poured',
#    'acid',
#    'into',
#    'his',
#    'eyes',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[9, 10], [12, 13]]},
#  {'id': '8052',
#   'tokens': ['The',
#    'room',
#    'was',
#    'filled',
#    'with',
#    'huge',
#    'Jack-the-Dripper',
#    'canvases',
#    '.'],
#   'label': 'Other',
#   'entities': [[7, 8], [1, 2]]},
#  {'id': '8053',
#   'tokens': ['The',
#    'gulp',
#    'of',
#    'magpies',
#    'just',
#    'left',
#    'after',
#    'a',
#    'quick',
#    'breakfast',
#    'of',
#    'peanuts',
#    'and',
#    'cookie',
#    'crumbs',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[3, 4], [1, 2]]},
#  {'id': '8054',
#   'tokens': ['The',
#    'proposal',
#    'was',
#    'debated',
#    'and',
#    'enthusiastically',
#    'endorsed',
#    'in',
#    '2002',
#    'by',
#    'a',
#    'convocation',
#    'of',
#    'international',
#    'scholars',
#    'that',
#    'included',
#    'many',
#    'prominent',
#    'academics',
#    ',',
#    'among',
#    'them',
#    'scientists',
#    'of',
#    'the',
#    'stature',
#    'of',
#    'the',
#    'late',
#    'H',
#    '.',
#    'Curien',
#    ',',
#    'H',
#    '.',
#    'Varmus',
#    ',',
#    'P',
#    '.',
#    'Crutzen',
#    'and',
#    'J',
#    '.',
#    'Sachs',
#    '.'],
#   'label': 'Other',
#   'entities': [[14, 15], [11, 12]]},
#  {'id': '8055',
#   'tokens': ['In',
#    'South',
#    'Africa',
#    ',',
#    'which',
#    'has',
#    'one',
#    'of',
#    'the',
#    'best',
#    'police',
#    'to',
#    'public',
#    'ratios',
#    'on',
#    'the',
#    'continent',
#    ',',
#    'the',
#    'share',
#    'of',
#    'murders',
#    'that',
#    'result',
#    'in',
#    'a',
#    'conviction',
#    'is',
#    'about',
#    '18%',
#    ',',
#    'compared',
#    'to',
#    '56%',
#    'in',
#    'the',
#    'US',
#    'and',
#    '61%',
#    'in',
#    'the',
#    'UK',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[21, 22], [26, 27]]},
#  {'id': '8056',
#   'tokens': ['A',
#    'group',
#    'of',
#    'monkeys',
#    'who',
#    'escaped',
#    'from',
#    'an',
#    'enclosure',
#    'at',
#    'Edinburgh',
#    'Zoo',
#    'are',
#    'one',
#    'step',
#    'from',
#    'being',
#    'caught',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[3, 4], [8, 9]]},
#  {'id': '8057',
#   'tokens': ['People',
#    'now',
#    'post',
#    'their',
#    'opinions',
#    'to',
#    'this',
#    'blog',
#    '.'],
#   'label': 'Other',
#   'entities': [[7, 8], [4, 5]]},
#  {'id': '8058',
#   'tokens': ['Traffic',
#    'vibrations',
#    'on',
#    'the',
#    'street',
#    'outside',
#    'had',
#    'caused',
#    'the',
#    'movement',
#    'of',
#    'the',
#    'light',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[1, 2], [9, 10]]},
#  {'id': '8059',
#   'tokens': ['Poodles',
#    'of',
#    'all',
#    'types',
#    'were',
#    'the',
#    'ideal',
#    'circus',
#    'dogs',
#    'when',
#    'not',
#    'dyed',
#    'pink',
#    'and',
#    'wearing',
#    'diamond',
#    'colliers',
#    'in',
#    'Via',
#    'Veneto',
#    'or',
#    'Maxim',
#    "'",
#    's',
#    '.'],
#   'label': 'Other',
#   'entities': [[16, 17], [15, 16]]},
#  {'id': '8060',
#   'tokens': ['A',
#    'digital',
#    'door',
#    'lock',
#    'is',
#    'an',
#    'electronic',
#    'lock',
#    'for',
#    'residential',
#    'applications',
#    'such',
#    'as',
#    'front',
#    'doors',
#    'on',
#    'apartments',
#    'and',
#    'single-family',
#    'houses',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[3, 4], [2, 3]]},
#  {'id': '8061',
#   'tokens': ['Red',
#    'grape',
#    'wine',
#    'is',
#    'an',
#    'alcoholic',
#    'fruit',
#    'drink',
#    'of',
#    'between',
#    '10',
#    'and',
#    '14%',
#    'alcoholic',
#    'strength',
#    '.'],
#   'label': 'Entity-Origin(e2,e1)',
#   'entities': [[2, 3], [0, 2]]},
#  {'id': '8062',
#   'tokens': ['The',
#    'text',
#    'also',
#    'exists',
#    'in',
#    'a',
#    'transcript',
#    'by',
#    'a',
#    'professional',
#    'scribe',
#    ',',
#    'which',
#    'was',
#    'prepared',
#    'for',
#    'Sir',
#    'Dudley',
#    'Carleton',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[6, 7], [10, 11]]},
#  {'id': '8063',
#   'tokens': ['A',
#    'witch',
#    'is',
#    'able',
#    'to',
#    'change',
#    'events',
#    'by',
#    'using',
#    'magic',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[9, 10], [1, 2]]},
#  {'id': '8064',
#   'tokens': ['The',
#    'committee',
#    'is',
#    'an',
#    'integral',
#    'part',
#    'of',
#    'our',
#    'organisation',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[1, 2], [8, 9]]},
#  {'id': '8065',
#   'tokens': ['I',
#    'have',
#    'inserted',
#    'a',
#    'clock',
#    'into',
#    'the',
#    'presentations',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[4, 5], [7, 8]]},
#  {'id': '8066',
#   'tokens': ['The',
#    'family',
#    'constructed',
#    'some',
#    'TCU',
#    'Horned',
#    'Frog',
#    'supporting',
#    'snow',
#    'features',
#    'as',
#    'well',
#    'as',
#    'just',
#    'a',
#    'really',
#    'nice',
#    'picture',
#    'of',
#    'an',
#    'old',
#    'fashioned',
#    'light',
#    'post',
#    '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[9, 10], [1, 2]]},
#  {'id': '8067',
#   'tokens': ['One',
#    'simple',
#    'method',
#    'for',
#    'clearing',
#    'small',
#    'clogs',
#    'is',
#    'to',
#    'use',
#    'a',
#    'tried-and-true',
#    'combination',
#    'of',
#    'baking',
#    'soda',
#    'and',
#    'vinegar',
#    '.'],
#   'label': 'Other',
#   'entities': [[12, 13], [2, 3]]},
#  {'id': '8068',
#   'tokens': ['The',
#    'complete',
#    'statue',
#    ',',
#    'topped',
#    'by',
#    'an',
#    'imposing',
#    'head',
#    ',',
#    'was',
#    'originally',
#    'nearly',
#    'five',
#    'metres',
#    'high',
#    '.'],
#   'label': 'Other',
#   'entities': [[8, 9], [2, 3]]},
#  {'id': '8069',
#   'tokens': ['In',
#    'the',
#    'article',
#    ',',
#    'the',
#    'authors',
#    'explore',
#    'the',
#    'use',
#    'of',
#    'technology',
#    'in',
#    'small',
#    'pharmacy',
#    'chains',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[2, 3], [8, 9]]},
#  {'id': '8070',
#   'tokens': ['The',
#    'following',
#    'comments',
#    'are',
#    'provided',
#    'by',
#    'readers',
#    'and',
#    'are',
#    'the',
#    'sole',
#    'responsiblity',
#    'of',
#    'the',
#    'authors',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[2, 3], [6, 7]]},
#  {'id': '8071',
#   'tokens': ['The',
#    'Organic',
#    'Act',
#    'of',
#    '1868',
#    'made',
#    'several',
#    'specific',
#    'references',
#    'to',
#    'the',
#    'powers',
#    'and',
#    'duties',
#    'of',
#    'the',
#    'president',
#    'of',
#    'the',
#    'university',
#    'after',
#    'stating',
#    'that',
#    'he',
#    'be',
#    'elected',
#    'to',
#    'office',
#    'by',
#    'the',
#    'Board',
#    'of',
#    'Regents',
#    '.'],
#   'label': 'Other',
#   'entities': [[19, 20], [16, 17]]},
#  {'id': '8072',
#   'tokens': ['This',
#    'grand',
#    'cru',
#    'wine',
#    'is',
#    'made',
#    'from',
#    'Pinot',
#    'Noir',
#    'grapes',
#    'and',
#    'is',
#    'medium',
#    'to',
#    'full-bodied',
#    'in',
#    'style',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[3, 4], [9, 10]]},
#  {'id': '8073',
#   'tokens': ['The',
#    'slide',
#    ',',
#    'which',
#    'was',
#    'triggered',
#    'by',
#    'an',
#    'avalanche-control',
#    'crew',
#    ',',
#    'damaged',
#    'one',
#    'home',
#    'and',
#    'blocked',
#    'the',
#    'road',
#    'for',
#    'most',
#    'of',
#    'the',
#    'day',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[9, 10], [1, 2]]},
#  {'id': '8074',
#   'tokens': ['Since',
#    'the',
#    'inspector',
#    'had',
#    'left',
#    'the',
#    'yard',
#    ',',
#    'early',
#    'that',
#    'morning',
#    ',',
#    'he',
#    'had',
#    'disappeared',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[2, 3], [6, 7]]},
#  {'id': '8075',
#   'tokens': ['International',
#    'ship',
#    'sewage',
#    'regulations',
#    'have',
#    'entered',
#    'into',
#    'force',
#    '.'],
#   'label': 'Other',
#   'entities': [[7, 8], [3, 4]]},
#  {'id': '8076',
#   'tokens': ['Ambassador',
#    'SUN',
#    'Shuzhong',
#    'answered',
#    'the',
#    'questions',
#    'from',
#    'the',
#    'local',
#    'press',
#    'after',
#    'his',
#    'visit',
#    'to',
#    'the',
#    'Memorial',
#    'Center',
#    'in',
#    'Kigali',
#    'on',
#    'Dec',
#    '.',
#    '28',
#    ',',
#    '2007',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[5, 6], [9, 10]]},
#  {'id': '8077',
#   'tokens': ['Her', 'children', 'have', 'gone', 'into', 'exile', '.'],
#   'label': 'Other',
#   'entities': [[5, 6], [1, 2]]},
#  {'id': '8078',
#   'tokens': ['A',
#    'Bedouin',
#    'mediator',
#    'again',
#    'returned',
#    'her',
#    'when',
#    'her',
#    'father',
#    'promised',
#    'not',
#    'to',
#    'hurt',
#    'her',
#    ',',
#    'and',
#    'then',
#    'her',
#    'father',
#    'killed',
#    'her',
#    'with',
#    'an',
#    'iron',
#    'bar',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[24, 25], [18, 19]]},
#  {'id': '8079',
#   'tokens': ['He',
#    'put',
#    'a',
#    'rebound',
#    'into',
#    'an',
#    'open',
#    'net',
#    'for',
#    'his',
#    'eighth',
#    'goal',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[3, 4], [7, 8]]},
#  {'id': '8080',
#   'tokens': ['The',
#    'UBC',
#    'graduate',
#    'student',
#    'spent',
#    'his',
#    'free',
#    'time',
#    'creating',
#    'an',
#    'application',
#    'called',
#    'ColorSplash',
#    'that',
#    'lets',
#    'people',
#    'play',
#    'with',
#    'the',
#    'colour',
#    'in',
#    'their',
#    'digital',
#    'photos',
#    '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[10, 11], [3, 4]]},
#  {'id': '8081',
#   'tokens': ['The',
#    'safety',
#    'bar',
#    'of',
#    'the',
#    'seats',
#    'has',
#    'to',
#    'be',
#    'folded',
#    'down',
#    'by',
#    'the',
#    'passenger',
#    'and',
#    'it',
#    'has',
#    'to',
#    'be',
#    'kept',
#    'closed',
#    'during',
#    'the',
#    'journey',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[2, 3], [5, 6]]},
#  {'id': '8082',
#   'tokens': ['By',
#    '1715',
#    'the',
#    'cabriole',
#    'leg',
#    'was',
#    'in',
#    'general',
#    'use',
#    ',',
#    'and',
#    'the',
#    'back',
#    'of',
#    'the',
#    'chair',
#    'had',
#    'started',
#    'to',
#    'become',
#    'square',
#    'in',
#    'shape:',
#    'no',
#    'longer',
#    'was',
#    'it',
#    'the',
#    'characteristic',
#    'tall',
#    'and',
#    'narrow',
#    'feature',
#    'of',
#    'the',
#    'previous',
#    'century',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[12, 13], [15, 16]]},
#  {'id': '8083',
#   'tokens': ['Muscle',
#    'fatigue',
#    'is',
#    'the',
#    'number',
#    'one',
#    'cause',
#    'of',
#    'arm',
#    'muscle',
#    'pain',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[1, 2], [10, 11]]},
#  {'id': '8084',
#   'tokens': ['Lawhammer',
#    'coat:',
#    'A',
#    'slang',
#    'term',
#    'for',
#    'a',
#    'man',
#    "'",
#    's',
#    'formal',
#    'evening',
#    'coat',
#    ',',
#    'because',
#    'split',
#    'tails',
#    'resemble',
#    'the',
#    'claw',
#    'of',
#    'a',
#    'hammer',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[19, 20], [22, 23]]},
#  {'id': '8085',
#   'tokens': ['The',
#    'magazine',
#    'was',
#    'founded',
#    'in',
#    'order',
#    'to',
#    'keep',
#    'athletes',
#    'serving',
#    'as',
#    'soldiers',
#    'informed',
#    'about',
#    'their',
#    'sport',
#    'back',
#    'home',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [15, 16]]},
#  {'id': '8086',
#   'tokens': ['Many',
#    'professional',
#    'cartomancers',
#    'use',
#    'a',
#    'regular',
#    'deck',
#    'of',
#    'playing',
#    'cards',
#    'for',
#    'divination',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[9, 10], [2, 3]]},
#  {'id': '8087',
#   'tokens': ['Many',
#    'films',
#    'have',
#    'portrayed',
#    'mental',
#    'illness',
#    'or',
#    'used',
#    'it',
#    'as',
#    'a',
#    'backdrop',
#    'for',
#    'other',
#    'themes',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [4, 6]]},
#  {'id': '8088',
#   'tokens': ['The',
#    'software',
#    'company',
#    'addressed',
#    'the',
#    'problem',
#    'with',
#    'the',
#    'publication',
#    'of',
#    'a',
#    'fix',
#    'on',
#    'Saturday',
#    '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[8, 9], [2, 3]]},
#  {'id': '8089',
#   'tokens': ['Drinking',
#    'down',
#    'the',
#    'rest',
#    'of',
#    'his',
#    'papaya',
#    'nectar',
#    ',',
#    'and',
#    'wiping',
#    'his',
#    'mouth',
#    'he',
#    'turned',
#    'and',
#    'hurried',
#    'away',
#    'throwing',
#    'a',
#    'goodbye',
#    'and',
#    'wave',
#    'over',
#    'his',
#    'shoulder',
#    'madly',
#    'dashing',
#    'thorough',
#    'the',
#    'crowds',
#    '.'],
#   'label': 'Entity-Origin(e2,e1)',
#   'entities': [[7, 8], [6, 7]]},
#  {'id': '8090',
#   'tokens': ['This',
#    'volume',
#    'analyzes',
#    'central',
#    'concepts',
#    'of',
#    'the',
#    'contemporary',
#    'political',
#    'debate',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [4, 5]]},
#  {'id': '8091',
#   'tokens': ['The',
#    'defendant',
#    'was',
#    'released',
#    'from',
#    'custody',
#    'on',
#    'March',
#    '2',
#    ',',
#    '2001',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[1, 2], [5, 6]]},
#  {'id': '8092',
#   'tokens': ['In',
#    'addition',
#    ',',
#    'the',
#    'plant',
#    'builds',
#    'four-cylinder',
#    '"Ecotec"',
#    'that',
#    'are',
#    'used',
#    'in',
#    'vehicles',
#    'like',
#    'the',
#    'Chevy',
#    'Malibu',
#    'and',
#    'Cobalt',
#    '.'],
#   'label': 'Other',
#   'entities': [[12, 13], [4, 5]]},
#  {'id': '8093',
#   'tokens': ['We',
#    'used',
#    'fried',
#    'cheese',
#    'as',
#    'an',
#    'element',
#    'in',
#    'a',
#    'dish',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[3, 4], [9, 10]]},
#  {'id': '8094',
#   'tokens': ['The', 'castle', 'was', 'inside', 'a', 'museum', '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[1, 2], [5, 6]]},
#  {'id': '8095',
#   'tokens': ['More',
#    'and',
#    'more',
#    'English',
#    'Premier',
#    'League',
#    'clubs',
#    'are',
#    'falling',
#    'into',
#    'foreign',
#    'ownership',
#    '.'],
#   'label': 'Other',
#   'entities': [[11, 12], [6, 7]]},
#  {'id': '8096',
#   'tokens': ['The',
#    'man',
#    'was',
#    'carried',
#    'into',
#    'a',
#    'waiting',
#    'police',
#    'car',
#    'from',
#    'Coleraine',
#    'Times',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[1, 2], [8, 9]]},
#  {'id': '8097',
#   'tokens': ['The',
#    'aim',
#    'of',
#    'this',
#    'section',
#    'is',
#    'the',
#    'interpretation',
#    'of',
#    'the',
#    'results',
#    'and',
#    'their',
#    'relation',
#    'to',
#    'the',
#    'existing',
#    'knowledge',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[4, 5], [7, 8]]},
#  {'id': '8098',
#   'tokens': ['Bunn',
#    'has',
#    'recalled',
#    '35',
#    ',',
#    '600',
#    'single-cup',
#    'pod',
#    'brewers',
#    'because',
#    'the',
#    'drawer',
#    'of',
#    'the',
#    'coffeemaker',
#    'opens',
#    'unexpectedly',
#    'during',
#    'a',
#    'brew',
#    'cycle',
#    ',',
#    'posing',
#    'a',
#    'burn',
#    'hazard',
#    'to',
#    'consumers',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[11, 12], [14, 15]]},
#  {'id': '8099',
#   'tokens': ['A',
#    'probe',
#    'tube',
#    'is',
#    'introduced',
#    'into',
#    'a',
#    'reaction',
#    'container',
#    'for',
#    'measuring',
#    'the',
#    'operating',
#    'condition',
#    'of',
#    'a',
#    'medium',
#    'in',
#    'the',
#    'interior',
#    'of',
#    'the',
#    'container',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[2, 3], [8, 9]]},
#  {'id': '8100',
#   'tokens': ['David',
#    'Mamet',
#    'took',
#    'questions',
#    'from',
#    'the',
#    'audience',
#    'and',
#    'shared',
#    'his',
#    'views',
#    'on',
#    'topics',
#    'such',
#    'as',
#    'television',
#    ',',
#    'the',
#    'democracy',
#    'of',
#    'culture',
#    'and',
#    'the',
#    'English',
#    'accent',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[10, 11], [15, 16]]},
#  {'id': '8101',
#   'tokens': ['Additionally',
#    ',',
#    'the',
#    'chapter',
#    'points',
#    'out',
#    'the',
#    'importance',
#    'of',
#    'new',
#    'employee',
#    'orientation',
#    'and',
#    'lists',
#    'some',
#    'of',
#    'the',
#    'important',
#    'things',
#    'to',
#    'cover',
#    'during',
#    'that',
#    'process',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[3, 4], [7, 8]]},
#  {'id': '8102',
#   'tokens': ['The',
#    'monitoring',
#    'station',
#    'receives',
#    'the',
#    'signal',
#    'through',
#    'a',
#    'communication',
#    'device',
#    'and',
#    'the',
#    'combined',
#    'signal',
#    'is',
#    'processed',
#    'to',
#    'retrieve',
#    'GPS',
#    'data',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[9, 10], [2, 3]]},
#  {'id': '8103',
#   'tokens': ['In',
#    'this',
#    'approach',
#    ',',
#    'correction',
#    'and',
#    'police',
#    'personnel',
#    'jointly',
#    'sought',
#    'to',
#    'locate',
#    'and',
#    'apprehend',
#    'offenders',
#    'who',
#    'had',
#    'absconded',
#    'from',
#    'parole',
#    'and',
#    'probation',
#    'officers',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[14, 15], [22, 23]]},
#  {'id': '8104',
#   'tokens': ['The',
#    'major',
#    'theme',
#    'of',
#    'the',
#    'book',
#    'is',
#    'the',
#    'beauty',
#    'of',
#    'a',
#    'dream',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[5, 6], [8, 9]]},
#  {'id': '8105',
#   'tokens': ['It',
#    'spilled',
#    'more',
#    'than',
#    '53000',
#    'gallons',
#    'of',
#    'crude',
#    'oil',
#    'into',
#    'the',
#    'surrounding',
#    'marshes',
#    'one',
#    'of',
#    'the',
#    'bigger',
#    'spills',
#    'caused',
#    'by',
#    'the',
#    'hurricane',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[21, 22], [17, 18]]},
#  {'id': '8106',
#   'tokens': ['Eighteen',
#    'studies',
#    'were',
#    'focused',
#    'on',
#    'older',
#    'adults',
#    'living',
#    'at',
#    'home',
#    '.'],
#   'label': 'Other',
#   'entities': [[6, 7], [1, 2]]},
#  {'id': '8107',
#   'tokens': ['The',
#    'diseases',
#    'are',
#    'caused',
#    'by',
#    'gene',
#    'mutations',
#    'on',
#    'the',
#    'X',
#    'chromosome',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[5, 7], [1, 2]]},
#  {'id': '8108',
#   'tokens': ['The',
#    'pretexts',
#    'offered',
#    'were',
#    'laughable',
#    ',',
#    'and',
#    'the',
#    'response',
#    'caused',
#    'scarcely',
#    'a',
#    'ripple',
#    'on',
#    'the',
#    'flood',
#    'of',
#    'commentary',
#    'on',
#    'Washington',
#    "'",
#    's',
#    'noble',
#    '"efforts',
#    'to',
#    'spread',
#    'democracy"',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[8, 9], [12, 13]]},
#  {'id': '8109',
#   'tokens': ['The',
#    'size',
#    'of',
#    'a',
#    'tree',
#    'crown',
#    'is',
#    'strongly',
#    'correlated',
#    'with',
#    'the',
#    'growth',
#    'of',
#    'the',
#    'tree',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[5, 6], [4, 5]]},
#  {'id': '8110',
#   'tokens': ['The',
#    'State',
#    'Capital',
#    'is',
#    'a',
#    'disgusting',
#    'sewer',
#    'and',
#    'Bruno',
#    'is',
#    'just',
#    'one',
#    'in',
#    'the',
#    'mischief',
#    'of',
#    'filthy',
#    'rats',
#    'that',
#    'proliferate',
#    'there',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[17, 18], [14, 15]]},
#  {'id': '8111',
#   'tokens': ['Sci-Fi',
#    'Channel',
#    'is',
#    'the',
#    'cable',
#    'network',
#    'exclusively',
#    'dedicated',
#    'to',
#    'offering',
#    'classic',
#    'science',
#    'fiction',
#    'TV',
#    'shows',
#    'and',
#    'movies',
#    ',',
#    'as',
#    'well',
#    'as',
#    'bold',
#    'original',
#    'programming',
#    '.'],
#   'label': 'Other',
#   'entities': [[11, 15], [4, 6]]},
#  {'id': '8112',
#   'tokens': ['The',
#    'mummified',
#    'cat',
#    'was',
#    'found',
#    'in',
#    'a',
#    'live',
#    'trap',
#    'with',
#    'an',
#    'empty',
#    'dish',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[2, 3], [8, 9]]},
#  {'id': '8113',
#   'tokens': ['The', 'stories', 'are', 'narrated', 'through', 'dance', '.'],
#   'label': 'Other',
#   'entities': [[5, 6], [1, 2]]},
#  {'id': '8114',
#   'tokens': ['The',
#    'foundry',
#    "'",
#    's',
#    'major',
#    'product',
#    'lines',
#    'include',
#    'manhole',
#    'frames',
#    'and',
#    'utility',
#    'covers',
#    ',',
#    'airport',
#    'castings',
#    ',',
#    'drainage',
#    'products',
#    ',',
#    'Trench',
#    'Grates',
#    ',',
#    'hydrant',
#    'and',
#    'valve',
#    'components',
#    ',',
#    'and',
#    'industrial',
#    'castings',
#    '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[9, 10], [1, 2]]},
#  {'id': '8115',
#   'tokens': ['The',
#    'air',
#    'was',
#    'filled',
#    'with',
#    'the',
#    'smell',
#    'of',
#    'burning',
#    'plastic',
#    '.'],
#   'label': 'Other',
#   'entities': [[6, 7], [1, 2]]},
#  {'id': '8116',
#   'tokens': ['Lisa',
#    'took',
#    'great',
#    'joy',
#    'from',
#    'laughing',
#    ',',
#    'volunteering',
#    'at',
#    'school',
#    ',',
#    'taking',
#    'pictures',
#    ',',
#    'chatting',
#    ',',
#    'the',
#    'Twins',
#    'and',
#    'Vikings',
#    ',',
#    'playing',
#    'softball',
#    'and',
#    'volleyball',
#    ',',
#    'and',
#    'time',
#    'at',
#    'Lake',
#    'Vermilion',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[5, 6], [3, 4]]},
#  {'id': '8117',
#   'tokens': ['Such',
#    'lines',
#    'from',
#    'the',
#    'pen',
#    'of',
#    'a',
#    'young',
#    'author',
#    'widely',
#    'read',
#    'by',
#    'the',
#    'younger',
#    'part',
#    'of',
#    'the',
#    'population',
#    'only',
#    'confirm',
#    'the',
#    'profound',
#    'change',
#    'in',
#    'the',
#    'mood',
#    'of',
#    'the',
#    'Freuch',
#    'proletariat',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[1, 2], [8, 9]]},
#  {'id': '8118',
#   'tokens': ['The',
#    'receiver',
#    'was',
#    'outputting',
#    'the',
#    'same',
#    'tone',
#    'to',
#    'my',
#    'Deva',
#    '5',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[1, 2], [6, 7]]},
#  {'id': '8119',
#   'tokens': ['At',
#    'least',
#    '12',
#    'people',
#    'were',
#    'killed',
#    'yesterday',
#    'when',
#    'a',
#    'squad',
#    'of',
#    'heavily',
#    'armed',
#    'militants',
#    'stormed',
#    'the',
#    'police',
#    'training',
#    'school',
#    'on',
#    'the',
#    'outskirts',
#    'of',
#    'Lahore',
#    ',',
#    'spraying',
#    'it',
#    'with',
#    'gunfire',
#    'and',
#    'grenades',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[13, 14], [9, 10]]},
#  {'id': '8120',
#   'tokens': ['The',
#    'telescope',
#    'comprises',
#    'lenses',
#    'and',
#    'tubes:',
#    'both',
#    'are',
#    'extremely',
#    'important',
#    'to',
#    'the',
#    'performance',
#    'of',
#    'the',
#    'telescope',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[3, 4], [1, 2]]},
#  {'id': '8121',
#   'tokens': ['We',
#    'poured',
#    'the',
#    'pulp',
#    'into',
#    'the',
#    'tupperware',
#    'tub',
#    'filled',
#    'with',
#    'water',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[3, 4], [6, 8]]},
#  {'id': '8122',
#   'tokens': ['Carpenters',
#    'build',
#    'many',
#    'things',
#    'from',
#    'wood',
#    'and',
#    'other',
#    'materials',
#    ',',
#    'like',
#    'buildings',
#    'and',
#    'boats',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[5, 6], [0, 1]]},
#  {'id': '8123',
#   'tokens': ['Milk',
#    'samples',
#    'were',
#    'obtained',
#    'from',
#    'one',
#    'milking',
#    'of',
#    'each',
#    'cow',
#    '.'],
#   'label': 'Other',
#   'entities': [[6, 7], [1, 2]]},
#  {'id': '8124',
#   'tokens': ['There',
#    "'",
#    's',
#    'a',
#    'comparison',
#    'between',
#    'the',
#    'intimacy',
#    'and',
#    'accountability',
#    'offered',
#    'by',
#    'a',
#    'novel',
#    'and',
#    'that',
#    'offered',
#    'by',
#    'a',
#    'blog',
#    'in',
#    'which',
#    'the',
#    'blogger',
#    'is',
#    'participant',
#    'in',
#    'an',
#    'on',
#    'going',
#    'conversation',
#    ',',
#    'in',
#    'which',
#    'the',
#    'line',
#    'between',
#    'reader',
#    'and',
#    'original',
#    'poster',
#    'is',
#    'blurred',
#    'beyond',
#    'recognition',
#    ',',
#    'in',
#    'which',
#    'collective',
#    'comment',
#    'replaces',
#    'old-fashioned',
#    'ivory',
#    'tower',
#    'editing',
#    'with',
#    'a',
#    'kind',
#    'of',
#    'universal',
#    'peer',
#    'review',
#    '.'],
#   'label': 'Other',
#   'entities': [[30, 31], [23, 24]]},
#  {'id': '8125',
#   'tokens': ['His',
#    'speech',
#    'criticised',
#    'the',
#    'idea',
#    'of',
#    'religious',
#    'education',
#    'as',
#    'a',
#    'journey',
#    'around',
#    'the',
#    'various',
#    'religions',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [4, 5]]},
#  {'id': '8126',
#   'tokens': ['The',
#    'bread',
#    'prepared',
#    'with',
#    'rice',
#    'flour',
#    'was',
#    'considered',
#    'good',
#    'by',
#    '25%',
#    'of',
#    'the',
#    'assessors',
#    ',',
#    'regular',
#    'by',
#    '33%',
#    ',',
#    'very',
#    'bad',
#    'by',
#    '17%',
#    'and',
#    'very',
#    'good',
#    'by',
#    'only',
#    '8%',
#    '.'],
#   'label': 'Entity-Origin(e2,e1)',
#   'entities': [[5, 6], [4, 5]]},
#  {'id': '8127',
#   'tokens': ['The',
#    'body',
#    'unleashes',
#    'its',
#    'extraterrestrial',
#    'passenger',
#    ',',
#    'which',
#    'proceeds',
#    'to',
#    'infect',
#    'the',
#    'student',
#    'population',
#    'at',
#    'a',
#    'breakneck',
#    'pace',
#    '.'],
#   'label': 'Entity-Origin(e2,e1)',
#   'entities': [[5, 6], [1, 2]]},
#  {'id': '8128',
#   'tokens': ['Asteroid', 'threatened', 'Earth', 'with', 'disaster', '.'],
#   'label': 'Other',
#   'entities': [[4, 5], [0, 1]]},
#  {'id': '8129',
#   'tokens': ['In',
#    'its',
#    'early',
#    'years',
#    'the',
#    'farm',
#    'had',
#    'forty',
#    'acres',
#    ',',
#    'and',
#    'was',
#    'a',
#    'productive',
#    'subsistence',
#    'farm',
#    'with',
#    'sheep',
#    'being',
#    'the',
#    'primary',
#    'source',
#    'of',
#    'income',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[8, 9], [5, 6]]},
#  {'id': '8130',
#   'tokens': ['The',
#    'laptop',
#    'was',
#    'inside',
#    'a',
#    'protective',
#    'plastic',
#    'bag',
#    'made',
#    'from',
#    'LDPE',
#    'number',
#    '4',
#    ',',
#    'which',
#    'can',
#    'be',
#    'easily',
#    'recycled',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[1, 2], [6, 8]]},
#  {'id': '8131',
#   'tokens': ['Gary',
#    'Wheelan',
#    ',',
#    'a',
#    'womanizing',
#    ',',
#    'adulterous',
#    'thirty-something',
#    'Dallas',
#    'attorney',
#    ',',
#    'finally',
#    'gets',
#    'what',
#    'he',
#    'deserves',
#    'when',
#    'his',
#    'verbal',
#    'assaults',
#    'provoke',
#    'a',
#    'telephone',
#    'operator',
#    '.'],
#   'label': 'Instrument-Agency(e1,e2)',
#   'entities': [[22, 23], [23, 24]]},
#  {'id': '8132',
#   'tokens': ['He',
#    'weaves',
#    'complex',
#    'tales',
#    'concerning',
#    'the',
#    'romantic',
#    'concerns',
#    'of',
#    'happiness',
#    ',',
#    'love',
#    'and',
#    'sufferance',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[3, 4], [7, 8]]},
#  {'id': '8133',
#   'tokens': ['Unlike',
#    'the',
#    'forebrain',
#    '(telencephalon',
#    'or',
#    'cerebrum)',
#    'of',
#    'mammals',
#    ',',
#    'birds',
#    ',',
#    'and',
#    'fish',
#    ',',
#    'the',
#    'forebrain',
#    'of',
#    'amphibians',
#    'is',
#    'similar',
#    'across',
#    'all',
#    'three',
#    'orders',
#    'of',
#    'amphibians:',
#    'the',
#    'anurons',
#    '(frogs',
#    'and',
#    'toads)',
#    ',',
#    'the',
#    'urodiles',
#    '(salamanders',
#    'and',
#    'newts)',
#    ',',
#    'and',
#    'the',
#    'caecilians',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[15, 16], [17, 18]]},
#  {'id': '8134',
#   'tokens': ['After',
#    'handsome',
#    'renovations',
#    'at',
#    'various',
#    'locales',
#    ',',
#    'the',
#    'company',
#    'has',
#    'remodeled',
#    'a',
#    'church',
#    'into',
#    'a',
#    'home',
#    '.'],
#   'label': 'Other',
#   'entities': [[15, 16], [8, 9]]},
#  {'id': '8135',
#   'tokens': ['The',
#    'hidden',
#    'camera',
#    ',',
#    'found',
#    'by',
#    'a',
#    'security',
#    'guard',
#    ',',
#    'was',
#    'hidden',
#    'in',
#    'a',
#    'business',
#    'card-sized',
#    'leaflet',
#    'box',
#    'placed',
#    'at',
#    'an',
#    'unmanned',
#    'ATM',
#    'in',
#    'Tokyo',
#    "'",
#    's',
#    'Minato',
#    'Ward',
#    'in',
#    'early',
#    'September',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[2, 3], [16, 18]]},
#  {'id': '8136',
#   'tokens': ['With',
#    'our',
#    'help',
#    ',',
#    'non-profit',
#    'human',
#    'service',
#    'organizations',
#    'effectively',
#    'manage',
#    'their',
#    'resources',
#    'and',
#    'succeed',
#    'in',
#    'the',
#    'modern',
#    'era',
#    'of',
#    'human',
#    'services',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[11, 12], [7, 8]]},
#  {'id': '8137',
#   'tokens': ['The',
#    'swim',
#    'bladder',
#    'of',
#    'aquatic',
#    'animals',
#    'gives',
#    'them',
#    'the',
#    'ability',
#    'to',
#    'manioulate',
#    'gravity',
#    'and',
#    'should',
#    'be',
#    'researched',
#    'more',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[1, 3], [5, 6]]},
#  {'id': '8138',
#   'tokens': ['On',
#    'the',
#    'morning',
#    'of',
#    'the',
#    '16th',
#    'we',
#    'again',
#    'set',
#    'forward',
#    ',',
#    'accompanied',
#    'by',
#    'a',
#    'coffle',
#    'of',
#    'fourteen',
#    'asses',
#    ',',
#    'loaded',
#    'with',
#    'salt',
#    ',',
#    'bound',
#    'for',
#    'Sansanding',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[17, 18], [14, 15]]},
#  {'id': '8139',
#   'tokens': ['The',
#    'coloring',
#    'is',
#    'derived',
#    'from',
#    'the',
#    'Grand',
#    'Duke',
#    "'",
#    's',
#    'coat',
#    'of',
#    'arms',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[1, 2], [10, 13]]},
#  {'id': '8140',
#   'tokens': ['The',
#    'Constitutionalist',
#    'and',
#    'Republican',
#    'were',
#    'arm',
#    'in',
#    'arm;',
#    'and',
#    'the',
#    'Quaker',
#    'and',
#    'Presbyterian',
#    'forgot',
#    'their',
#    'religious',
#    'antipathies',
#    'in',
#    'this',
#    'coalition',
#    'of',
#    'interests',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[21, 22], [19, 20]]},
#  {'id': '8141',
#   'tokens': ['A',
#    'multi-purpose',
#    'electrician',
#    'pliers',
#    'tool',
#    'is',
#    'crucial',
#    'for',
#    'severing',
#    'any',
#    'gauge',
#    'wire',
#    'with',
#    'which',
#    'the',
#    'electrician',
#    'is',
#    'working',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[4, 5], [2, 3]]},
#  {'id': '8142',
#   'tokens': ['The',
#    'GPS',
#    'network',
#    'adjustment',
#    'of',
#    'data',
#    'from',
#    'both',
#    'epochs',
#    'is',
#    'accomplished',
#    'using',
#    'the',
#    'Ski',
#    'TM',
#    'software',
#    'with',
#    'constrains',
#    'network',
#    'adjustment',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[5, 6], [8, 9]]},
#  {'id': '8143',
#   'tokens': ['We', 'built', 'this', 'city', 'on', 'rock', 'and', 'roll', '.'],
#   'label': 'Other',
#   'entities': [[5, 8], [3, 4]]},
#  {'id': '8144',
#   'tokens': ['The',
#    'parents',
#    'went',
#    'away',
#    'from',
#    'the',
#    'police',
#    'station',
#    ',',
#    'since',
#    'they',
#    'were',
#    'poor',
#    '.'],
#   'label': 'Entity-Origin(e1,e2)',
#   'entities': [[1, 2], [7, 8]]},
#  {'id': '8145',
#   'tokens': ['William',
#    'H',
#    '.',
#    'Parker',
#    'was',
#    'the',
#    'longest',
#    'serving',
#    'police',
#    'chief',
#    'in',
#    'Los',
#    'Angeles',
#    'Police',
#    'Department',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[9, 10], [8, 9]]},
#  {'id': '8146',
#   'tokens': ['Hospitals',
#    'today',
#    'use',
#    'a',
#    '"blowby"',
#    'apparatus',
#    'for',
#    'this',
#    'purpose',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[5, 6], [0, 1]]},
#  {'id': '8147',
#   'tokens': ['The',
#    'boots',
#    'were',
#    'in',
#    'a',
#    'box',
#    'of',
#    'stuff',
#    'the',
#    'boys',
#    'picked',
#    'up',
#    'at',
#    'the',
#    'post',
#    'office',
#    'just',
#    'before',
#    'the',
#    'curtain',
#    'fell',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[1, 2], [5, 6]]},
#  {'id': '8148',
#   'tokens': ['Roadside',
#    'attractions',
#    'are',
#    'frequently',
#    'advertised',
#    'with',
#    'billboards',
#    'to',
#    'attract',
#    'tourists',
#    '.'],
#   'label': 'Message-Topic(e2,e1)',
#   'entities': [[6, 7], [1, 2]]},
#  {'id': '8149',
#   'tokens': ['Anyway',
#    ',',
#    'the',
#    'guy',
#    'convinced',
#    'some',
#    'local',
#    'with',
#    'a',
#    'car',
#    'to',
#    'drive',
#    'somewhere',
#    'to',
#    'procure',
#    'us',
#    'some',
#    'beer',
#    '.'],
#   'label': 'Other',
#   'entities': [[9, 10], [3, 4]]},
#  {'id': '8150',
#   'tokens': ['The',
#    'placenta',
#    'fully',
#    'functions',
#    'at',
#    'this',
#    'time',
#    'and',
#    'the',
#    'fetus',
#    'makes',
#    'insulin',
#    'and',
#    'urinates',
#    '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[11, 12], [9, 10]]},
#  {'id': '8151',
#   'tokens': ['The', 'design', 'is', 'by', 'my', 'wife', ',', 'Bianca', '.'],
#   'label': 'Product-Producer(e1,e2)',
# ...
#    'those',
#    'little',
#    'packages',
#    'that',
#    'are',
#    'almost',
#    'impossible',
#    'to',
#    'open',
#    'and',
#    'make',
#    'a',
#    'huge',
#    'mess',
#    'once',
#    'you',
#    'manage',
#    'to',
#    'do',
#    'so',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[7, 8], [11, 12]]},
#  {'id': '8951',
#   'tokens': ['Vehicles',
#    'are',
#    'equipped',
#    'with',
#    'front',
#    'and',
#    'rear',
#    'bumpers',
#    'designed',
#    'to',
#    'withstand',
#    'the',
#    'impact',
#    'of',
#    'the',
#    'collision',
#    '.'],
#   'label': 'Component-Whole(e2,e1)',
#   'entities': [[7, 8], [0, 1]]},
#  {'id': '8952',
#   'tokens': ['The',
#    'Japanese',
#    'team',
#    'conducted',
#    'their',
#    'preliminary',
#    'research',
#    'on',
#    'mice',
#    ',',
#    'with',
#    'a',
#    'cancer',
#    'gene',
#    'among',
#    'the',
#    'regulators',
#    ',',
#    'and',
#    'created',
#    'in',
#    'the',
#    'process',
#    'a',
#    'mischief',
#    'of',
#    'clone',
#    'mice',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[27, 28], [24, 25]]},
#  {'id': '8953',
#   'tokens': ['The',
#    'acidity',
#    'is',
#    'caused',
#    'by',
#    'the',
#    'gradual',
#    'buildup',
#    'of',
#    'carbon',
#    'dioxide',
#    '(CO2)',
#    'in',
#    'the',
#    'atmosphere',
#    ',',
#    'dissolving',
#    'into',
#    'the',
#    'oceans',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[9, 11], [1, 2]]},
#  {'id': '8954',
#   'tokens': ['The',
#    'European',
#    'colonial',
#    'expansion',
#    'to',
#    'the',
#    'Americas',
#    'resulted',
#    'in',
#    'massive',
#    'population',
#    'movements',
#    'from',
#    'the',
#    'Old',
#    'World',
#    'to',
#    'the',
#    'New',
#    'World',
#    '.'],
#   'label': 'Cause-Effect(e1,e2)',
#   'entities': [[3, 4], [11, 12]]},
#  {'id': '8955',
#   'tokens': ['Workers',
#    'take',
#    'wax',
#    'from',
#    'wax',
#    'producing',
#    'workers',
#    'and',
#    'build',
#    'the',
#    'comb',
#    'with',
#    'it',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[4, 5], [6, 7]]},
#  {'id': '8956',
#   'tokens': ['The',
#    'author',
#    'identifies',
#    'the',
#    'Piper',
#    'with',
#    'the',
#    'devil',
#    '.'],
#   'label': 'Other',
#   'entities': [[7, 8], [1, 2]]},
#  {'id': '8957',
#   'tokens': ['A',
#    'faction',
#    'of',
#    'Sikh',
#    'leaders',
#    'took',
#    'over',
#    'a',
#    'gurdwara',
#    'in',
#    'this',
#    'Haryana',
#    'town',
#    ',',
#    'which',
#    'was',
#    'controlled',
#    'by',
#    'Amritsar-based',
#    'Shiromani',
#    'Gurdwara',
#    'Parbandhak',
#    'Committee',
#    '(SGPC)',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[4, 5], [1, 2]]},
#  {'id': '8958',
#   'tokens': ['The',
#    'law-maker',
#    'narrowly',
#    'escaped',
#    'by',
#    'fleeing',
#    'from',
#    'his',
#    'house',
#    'on',
#    'a',
#    'horse',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[11, 12], [1, 2]]},
#  {'id': '8959',
#   'tokens': ['When',
#    'the',
#    'loading',
#    'time',
#    'was',
#    'completed',
#    ',',
#    'the',
#    'sliding',
#    'bar',
#    'of',
#    'the',
#    'injector',
#    'was',
#    'displaced',
#    'manually',
#    'to',
#    'the',
#    'other',
#    'resting',
#    'position',
#    '(dashed',
#    'area)',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[9, 10], [12, 13]]},
#  {'id': '8960',
#   'tokens': ['Cambodian',
#    'troops',
#    'arrived',
#    'to',
#    'areas',
#    'in',
#    'Chad',
#    ',',
#    'Central',
#    'African',
#    'Republic',
#    'where',
#    'US',
#    'forces',
#    'had',
#    'settled',
#    'already',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[1, 2], [4, 5]]},
#  {'id': '8961',
#   'tokens': ['Highways', 'are', 'falling', 'into', 'disrepair', '.'],
#   'label': 'Other',
#   'entities': [[4, 5], [0, 1]]},
#  {'id': '8962',
#   'tokens': ['Witness',
#    'Ryan',
#    'Jones',
#    'tried',
#    'to',
#    'stop',
#    'the',
#    'fleeing',
#    'Diaz',
#    ',',
#    'Jones',
#    'became',
#    'caught',
#    'on',
#    'the',
#    'door',
#    'of',
#    'the',
#    'truck',
#    'and',
#    'was',
#    'dragged',
#    'for',
#    'a',
#    'distance',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[15, 16], [18, 19]]},
#  {'id': '8963',
#   'tokens': ['The',
#    'tea',
#    'was',
#    'in',
#    'a',
#    'mug',
#    'my',
#    'husband',
#    ',',
#    'Larry',
#    ',',
#    'had',
#    'ordered',
#    'from',
#    'some',
#    'company',
#    'online',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[1, 2], [5, 6]]},
#  {'id': '8964',
#   'tokens': ['While',
#    'making',
#    'observations',
#    'the',
#    'microfossil',
#    'through',
#    'the',
#    'binocular',
#    'microscope',
#    'or',
#    'on',
#    'a',
#    'computer',
#    'monitor',
#    ',',
#    'the',
#    'investigator',
#    'needed',
#    'to',
#    'manually',
#    'move',
#    'the',
#    'specimen',
#    '.'],
#   'label': 'Other',
#   'entities': [[13, 14], [2, 3]]},
#  {'id': '8965',
#   'tokens': ['A',
#    'while',
#    'ago',
#    'I',
#    'was',
#    'walking',
#    'along',
#    'the',
#    'Nibenay',
#    'Basin',
#    'when',
#    'I',
#    'stumbled',
#    'upon',
#    'a',
#    'harras',
#    'of',
#    'wild',
#    'horses',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[18, 19], [15, 16]]},
#  {'id': '8966',
#   'tokens': ['On',
#    'the',
#    'way',
#    'in',
#    'we',
#    'saw',
#    'a',
#    'big',
#    'raft',
#    'of',
#    'Eider',
#    'ducks',
#    'and',
#    'there',
#    'were',
#    'some',
#    'tiny',
#    'babies',
#    'with',
#    'them',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[11, 12], [8, 9]]},
#  {'id': '8967',
#   'tokens': ['Another',
#    '40',
#    'million',
#    'people',
#    'have',
#    'been',
#    'pushed',
#    'into',
#    'hunger',
#    'this',
#    'year',
#    '.'],
#   'label': 'Other',
#   'entities': [[8, 9], [3, 4]]},
#  {'id': '8968',
#   'tokens': ['He',
#    'grabbed',
#    'and',
#    'put',
#    'all',
#    'dirty',
#    'clothing',
#    'in',
#    'a',
#    'hamper',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[6, 7], [9, 10]]},
#  {'id': '8969',
#   'tokens': ['Each',
#    'recipe',
#    'features',
#    'an',
#    'anecdote',
#    'by',
#    'a',
#    'band',
#    'that',
#    'performed',
#    'via',
#    'the',
#    'Hope',
#    'Collective',
#    ',',
#    'a',
#    'popular',
#    'punk',
#    'booking',
#    'collective',
#    'in',
#    'Dublin',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[4, 5], [7, 8]]},
#  {'id': '8970',
#   'tokens': ['The',
#    'writer',
#    'has',
#    'a',
#    "'",
#    'bottle',
#    'of',
#    'ink',
#    ',',
#    'a',
#    'pen',
#    'and',
#    'a',
#    'blotter',
#    "'",
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[7, 8], [1, 2]]},
#  {'id': '8971',
#   'tokens': ['The',
#    'city',
#    'has',
#    'constructed',
#    'some',
#    'tourism',
#    'facilities',
#    'and',
#    'a',
#    'new',
#    'police',
#    'station',
#    'in',
#    'the',
#    'showcase',
#    'area',
#    ',',
#    'but',
#    'no',
#    'new',
#    'houses',
#    'are',
#    'to',
#    'be',
#    'built',
#    'here',
#    '.'],
#   'label': 'Product-Producer(e2,e1)',
#   'entities': [[11, 12], [1, 2]]},
#  {'id': '8972',
#   'tokens': ['The',
#    'straight',
#    ',',
#    'blue',
#    'ion',
#    'tail',
#    'is',
#    'caused',
#    'by',
#    'the',
#    'solar',
#    'wind',
#    'and',
#    'the',
#    'curved',
#    'dust',
#    'tail',
#    'is',
#    'caused',
#    'by',
#    'solar',
#    'radiation',
#    'pressure',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[10, 12], [5, 6]]},
#  {'id': '8973',
#   'tokens': ['The',
#    'ocean',
#    'exploration',
#    'is',
#    'now',
#    'moving',
#    'into',
#    'deeper',
#    'waters',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[2, 3], [8, 9]]},
#  {'id': '8974',
#   'tokens': ['Infectious',
#    'diseases',
#    'or',
#    'communicable',
#    'diseases',
#    'are',
#    'caused',
#    'by',
#    'bacteria',
#    ',',
#    'viruses',
#    ',',
#    'and',
#    'parasites',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[13, 14], [0, 2]]},
#  {'id': '8975',
#   'tokens': ['Proposals',
#    'to',
#    'simplify',
#    'the',
#    'university',
#    'admissions',
#    'process',
#    'have',
#    'been',
#    'outlined',
#    'at',
#    'a',
#    'conference',
#    'of',
#    'secondary',
#    'school',
#    'head',
#    'teachers',
#    '.'],
#   'label': 'Message-Topic(e2,e1)',
#   'entities': [[12, 13], [0, 1]]},
#  {'id': '8976',
#   'tokens': ['During',
#    'the',
#    'reign',
#    'of',
#    'King',
#    'Richard',
#    'II',
#    ',',
#    'this',
#    'was',
#    'replaced',
#    'by',
#    'a',
#    'hammerbeam',
#    'roof',
#    'by',
#    'the',
#    'royal',
#    'carpenter',
#    'Hugh',
#    'Herland',
#    ',',
#    '"the',
#    'greatest',
#    'creation',
#    'of',
#    'medieval',
#    'timber',
#    'architecture"',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[14, 15], [18, 19]]},
#  {'id': '8977',
#   'tokens': ['To',
#    'prepare',
#    'for',
#    'his',
#    'exam',
#    ',',
#    'the',
#    'student',
#    'visited',
#    'the',
#    'ISA',
#    'website',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[11, 12], [7, 8]]},
#  {'id': '8978',
#   'tokens': ['The',
#    'Football',
#    'Club',
#    'has',
#    'rescheduled',
#    'the',
#    'trials',
#    'to',
#    'the',
#    'next',
#    'day',
#    'due',
#    'to',
#    'recent',
#    'wet',
#    'weather',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[6, 7], [10, 11]]},
#  {'id': '8979',
#   'tokens': ['The',
#    'second',
#    'lesson',
#    'points',
#    'to',
#    'the',
#    'predominant',
#    'role',
#    'of',
#    'quality',
#    'over',
#    'quantity',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[2, 3], [6, 7]]},
#  {'id': '8980',
#   'tokens': ['Many',
#    'times',
#    ',',
#    'journalists',
#    'become',
#    'the',
#    'topic',
#    'for',
#    'discussion',
#    'among',
#    'political',
#    'party',
#    'supporters',
#    'at',
#    'press',
#    'conferences',
#    '.'],
#   'label': 'Message-Topic(e2,e1)',
#   'entities': [[8, 9], [3, 4]]},
#  {'id': '8981',
#   'tokens': ['Women',
#    'improve',
#    'lives',
#    'of',
#    'their',
#    'families',
#    'with',
#    'the',
#    'help',
#    'of',
#    'a',
#    'few',
#    'sheep',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[12, 13], [0, 1]]},
#  {'id': '8982',
#   'tokens': ['The',
#    'definition',
#    'of',
#    'the',
#    'vCard',
#    'Specification',
#    'made',
#    'use',
#    'of',
#    'a',
#    'number',
#    'of',
#    'existing',
#    'standards',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[13, 14], [1, 2]]},
#  {'id': '8983',
#   'tokens': ['All',
#    'your',
#    'posts',
#    'are',
#    'imported',
#    'into',
#    'the',
#    'standard',
#    'Wordpress',
#    'installation',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[2, 3], [9, 10]]},
#  {'id': '8984',
#   'tokens': ['Without',
#    'wasting',
#    'time',
#    ',',
#    'a',
#    'medical',
#    'team',
#    'of',
#    'the',
#    'army',
#    'rushed',
#    'to',
#    'the',
#    'house',
#    'of',
#    'the',
#    'militant',
#    'and',
#    'provided',
#    'emergent',
#    'medical',
#    'treatment',
#    'to',
#    'her',
#    '.'],
#   'label': 'Component-Whole(e1,e2)',
#   'entities': [[6, 7], [9, 10]]},
#  {'id': '8985',
#   'tokens': ['The',
#    'report',
#    'provides',
#    'a',
#    'full',
#    'account',
#    'of',
#    'the',
#    'societal',
#    'impacts',
#    'of',
#    'car',
#    'production',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[1, 2], [8, 10]]},
#  {'id': '8986',
#   'tokens': ['The',
#    'Siege',
#    'started',
#    'rather',
#    'slow',
#    ',',
#    'with',
#    'a',
#    'regiment',
#    'of',
#    'lightly',
#    'armored',
#    'swordsmen',
#    'ramming',
#    'down',
#    'the',
#    'gate',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[12, 13], [8, 9]]},
#  {'id': '8987',
#   'tokens': ['On',
#    'this',
#    'basis',
#    ',',
#    'the',
#    'vibronically',
#    'coupled',
#    'CD',
#    'bands',
#    'of',
#    'lutein',
#    'diacetate',
#    'are',
#    'attributed',
#    'to',
#    'an',
#    'excitonic',
#    'interaction',
#    'arose',
#    'from',
#    'the',
#    'twisted',
#    'nematic',
#    'layers',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[23, 24], [17, 18]]},
#  {'id': '8988',
#   'tokens': ['PSA',
#    'is',
#    'a',
#    'chemical',
#    'produced',
#    'exclusively',
#    'by',
#    'the',
#    'prostate',
#    'gland',
#    'to',
#    'liquefy',
#    'semen',
#    '.'],
#   'label': 'Product-Producer(e1,e2)',
#   'entities': [[3, 4], [9, 10]]},
#  {'id': '8989',
#   'tokens': ['The',
#    'pension',
#    'crisis',
#    'has',
#    'been',
#    'caused',
#    'by',
#    'the',
#    'escalating',
#    'cost',
#    'of',
#    'funding',
#    '"copper',
#    'bottomed"',
#    'final',
#    'salary',
#    'pension',
#    'schemes',
#    'still',
#    'provided',
#    ',',
#    'unlike',
#    'most',
#    'companies',
#    ',',
#    'by',
#    'councils',
#    'and',
#    'other',
#    'public',
#    'sector',
#    'employers',
#    'such',
#    'as',
#    'Transport',
#    'for',
#    'London',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[9, 10], [2, 3]]},
#  {'id': '8990',
#   'tokens': ['The',
#    'editors',
#    'have',
#    'inserted',
#    'narration',
#    'into',
#    'the',
#    'description',
#    '.'],
#   'label': 'Entity-Destination(e1,e2)',
#   'entities': [[4, 5], [7, 8]]},
#  {'id': '8991',
#   'tokens': ['A',
#    'blood',
#    'clot',
#    'is',
#    'a',
#    'normal',
#    'reaction',
#    'of',
#    'the',
#    'body',
#    'that',
#    'occurs',
#    'if',
#    'a',
#    'blood',
#    'vessel',
#    'is',
#    'injured',
#    '.'],
#   'label': 'Other',
#   'entities': [[2, 3], [1, 2]]},
#  {'id': '8992',
#   'tokens': ['A',
#    'third',
#    'of',
#    'the',
#    'injuries',
#    'are',
#    'caused',
#    'by',
#    'illegally',
#    'obtained',
#    'fireworks',
#    ',',
#    'and',
#    'burns',
#    'account',
#    'for',
#    'half',
#    'the',
#    'injuries',
#    '.'],
#   'label': 'Cause-Effect(e2,e1)',
#   'entities': [[10, 11], [4, 5]]},
#  {'id': '8993',
#   'tokens': ['The',
#    'icon',
#    'is',
#    'generally',
#    'a',
#    'flat',
#    'panel',
#    'painting',
#    'depicting',
#    'a',
#    'holy',
#    'being',
#    'or',
#    'object',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[7, 8], [11, 12]]},
#  {'id': '8994',
#   'tokens': ['The',
#    'weather',
#    'is',
#    'still',
#    'the',
#    'main',
#    'talking',
#    'point',
#    'on',
#    'the',
#    'front',
#    'pages',
#    '.'],
#   'label': 'Message-Topic(e2,e1)',
#   'entities': [[10, 12], [1, 2]]},
#  {'id': '8995',
#   'tokens': ['Their', 'relationship', 'is', 'thrown', 'into', 'chaos', '.'],
#   'label': 'Other',
#   'entities': [[5, 6], [1, 2]]},
#  {'id': '8996',
#   'tokens': ['I',
#    'wanted',
#    'to',
#    'breastfeed',
#    'him',
#    'when',
#    'he',
#    'was',
#    'hungry',
#    'and',
#    'I',
#    'noticed',
#    'that',
#    'he',
#    'wasn',
#    "'",
#    't',
#    'approving',
#    'of',
#    'my',
#    'breast',
#    ',',
#    'so',
#    'I',
#    'gave',
#    'him',
#    'a',
#    'bottle',
#    'with',
#    'formula',
#    'in',
#    'it',
#    '.'],
#   'label': 'Content-Container(e2,e1)',
#   'entities': [[29, 30], [27, 28]]},
#  {'id': '8997',
#   'tokens': ['The',
#    'mess',
#    'was',
#    'rapidly',
#    'cleaned',
#    'by',
#    'one',
#    'of',
#    'the',
#    'waiters',
#    'with',
#    'a',
#    'mop',
#    'and',
#    'disinfectant',
#    'and',
#    'the',
#    'meal',
#    'continued',
#    '.'],
#   'label': 'Instrument-Agency(e2,e1)',
#   'entities': [[12, 13], [9, 10]]},
#  {'id': '8998',
#   'tokens': ['The',
#    'skies',
#    'were',
#    'also',
#    'filled',
#    'with',
#    'a',
#    'desert',
#    'of',
#    'lapwings',
#    'and',
#    'a',
#    'congregation',
#    'of',
#    'golden',
#    'plover',
#    ',',
#    'mixed',
#    'together',
#    'in',
#    'a',
#    'cloud',
#    'of',
#    'birds',
#    'which',
#    'filled',
#    'the',
#    'sky',
#    'as',
#    'they',
#    'escaped',
#    'a',
#    'passing',
#    '(but',
#    'unseen',
#    'by',
#    'me)',
#    'predator',
#    '.'],
#   'label': 'Member-Collection(e2,e1)',
#   'entities': [[9, 10], [7, 8]]},
#  {'id': '8999',
#   'tokens': ['One',
#    'of',
#    'the',
#    'few',
#    'clear',
#    'and',
#    'non-controversial',
#    'norms',
#    'governing',
#    'issues',
#    'of',
#    'state',
#    'succession',
#    'are',
#    'the',
#    'customary',
#    'rules',
#    'enshrined',
#    'in',
#    'article',
#    '11',
#    '.'],
#   'label': 'Message-Topic(e1,e2)',
#   'entities': [[7, 8], [9, 10]]},
#  {'id': '9000',
#   'tokens': ['The',
#    'bomb',
#    'was',
#    'hidden',
#    'in',
#    'a',
#    'Toshiba',
#    'radio-cassette',
#    'player',
#    'which',
#    'in',
#    'turn',
#    ',',
#    'was',
#    'inside',
#    'a',
#    'brown',
#    'Samsonite',
#    'suitcase',
#    '.'],
#   'label': 'Content-Container(e1,e2)',
#   'entities': [[1, 2], [7, 9]]},
#  ...]

# %%
sentences = []
for v in original_data:
    sentences.append(' '.join(v['tokens']))
len(sentences)
# Out:
# 2717

# %%
for v in original_data:
    if len(v['entities'])>2:
        print(v)

# %%
[a,b],[c,d]=[[1,2],[3,4]]
a
# Out:
# 1

# %%
len(set(sentences))
# Out:
# 2715

# %%
from collections import defaultdict
import re


def clean(t):
    """
    Remove whitespaces within marked words
    """
    t = re.sub("<ARG0> ","<ARG0>", t)
    t = re.sub(" </ARG0>","</ARG0>", t)
    t = re.sub("<ARG1> ","<ARG1>", t)
    t = re.sub(" </ARG1>","</ARG1>", t)
    return t 


def run(file):
    # Open File
    fn = os.path.join(data_dir, file)
    original_data = open_json(fn, data_format=dict)
    
    def get_s_e_t_list(s_head=[], e_head=[], s_tail=[], e_tail=[]):
        s_locs, e_locs, tags = [], [], []
        if isinstance(s_head,(np.ndarray,list)):
            s_locs.extend(s_head)
            e_locs.extend(e_head)
            tags.extend(['<ARG0>']*len(s_head))
        else:
            s_locs.append(s_head)
            e_locs.append(e_head)
            tags.append('<ARG0>')

        if isinstance(s_tail,(np.ndarray,list)):
            s_locs.extend(s_tail)
            e_locs.extend(e_tail)
            tags.extend(['<ARG1>']*len(s_tail))
        else:
            s_locs.append(s_tail)
            e_locs.append(e_tail)
            tags.append('<ARG1>')
        return sorted(zip(s_locs, e_locs, tags))

    # Generate Examples
    corpus = 'semeval2010t8'
    cols = ['corpus','doc_id','sent_id','eg_id','index','text','text_w_pairs','seq_label','pair_label','context','num_sents']
    data = []
    text_to_sentid = {}
    sentid_counter = defaultdict(int)
    max_sentid = 0
    for v in original_data:

        # Get Sentence
        text = ' '.join(v['tokens'])
        
        # Check if we have sentence
        if text in text_to_sentid.keys():
            # If yes: Get sentid
            sentid = text_to_sentid[text]
        else:
            # If no: Create index
            text_to_sentid[text] = max_sentid
            sentid = max_sentid
            # Prepare for next round
            max_sentid += 1
        num_eg_for_this_sentid = sentid_counter[sentid]
        
        identifiers = [corpus,os.path.basename(fn),str(sentid),str(num_eg_for_this_sentid)]
        unique_index = '_'.join(identifiers)

        label = v['label']
        seq_label = pair_label = 1 if 'Cause-Effect' in label else 0

        # There is always only two entities
        [s_head, e_head], [s_tail, e_tail] = v['entities']
        added_t = 0
        text_w_pairs = v['tokens']
        for s,e,t in get_s_e_t_list(s_head, e_head, s_tail, e_tail):
            s += added_t
            e += added_t
            end_t = t[0]+'/'+t[1:]
            text_w_pairs = text_w_pairs[:s]+[t]+text_w_pairs[s:e]+[end_t]+text_w_pairs[e:]
            added_t+=2
        text_w_pairs = ' '.join(text_w_pairs)
        text_w_pairs = clean(text_w_pairs)
        
        data.append(
            identifiers+[
                unique_index,
                text.strip(),
                text_w_pairs.strip(),
                seq_label,
                pair_label,
                '',1
            ]
        )
        
        sentid_counter[sentid]+=1
    
    data = pd.DataFrame(data, columns=cols)
    data['sent_id'] = data['sent_id'].astype(str)
    data['seq_label'] = data.groupby(['corpus','doc_id','sent_id'])['seq_label'].transform('max')
        
    return data

file = all_filenames[1]
data = run(file)
data
# Out:
#              corpus     doc_id sent_id eg_id                           index  \
# 0     semeval2010t8  test.json       0     0     semeval2010t8_test.json_0_0
# 1     semeval2010t8  test.json       1     0     semeval2010t8_test.json_1_0
# 2     semeval2010t8  test.json       2     0     semeval2010t8_test.json_2_0
# 3     semeval2010t8  test.json       3     0     semeval2010t8_test.json_3_0
# 4     semeval2010t8  test.json       4     0     semeval2010t8_test.json_4_0
# ...             ...        ...     ...   ...                             ...
# 2712  semeval2010t8  test.json    2710     0  semeval2010t8_test.json_2710_0
# 2713  semeval2010t8  test.json    2711     0  semeval2010t8_test.json_2711_0
# 2714  semeval2010t8  test.json    2712     0  semeval2010t8_test.json_2712_0
# 2715  semeval2010t8  test.json    2713     0  semeval2010t8_test.json_2713_0
# 2716  semeval2010t8  test.json    2714     0  semeval2010t8_test.json_2714_0
#
#                                                    text  \
# 0     The most common audits were about waste and re...
# 1               The company fabricates plastic chairs .
# 2     The school master teaches the lesson with a st...
# 3     The suspect dumped the dead body into a local ...
# 4     Avian influenza is an infectious disease of bi...
# ...                                                 ...
# 2712  After seating all the idols , which itself tak...
# 2713  The minister attributed the slow production of...
# 2714  The umbrella frame is provided with a movable ...
# 2715  Manos: The Hands of Fate is a low-budget horro...
# 2716  A few days before the service , Tom Burris had...
#
#                                            text_w_pairs  seq_label  \
# 0     The most common <ARG0>audits</ARG0> were about...          0
# 1     The <ARG1>company</ARG1> fabricates plastic <A...          0
# 2     The school <ARG1>master</ARG1> teaches the les...          0
# 3     The suspect dumped the dead <ARG0>body</ARG0> ...          0
# 4     Avian <ARG1>influenza</ARG1> is an infectious ...          1
# ...                                                 ...        ...
# 2712  After seating all the idols , which itself tak...          0
# 2713  The minister attributed the slow production of...          0
# 2714  The <ARG1>umbrella</ARG1> <ARG0>frame</ARG0> i...          0
# 2715  Manos: The Hands of Fate is a low-budget horro...          0
# 2716  A few days before the service , Tom Burris had...          0
#
#       pair_label context  num_sents
# 0              0                  1
# 1              0                  1
# 2              0                  1
# 3              0                  1
# 4              1                  1
# ...          ...     ...        ...
# 2712           0                  1
# 2713           0                  1
# 2714           0                  1
# 2715           0                  1
# 2716           0                  1
#
# [2717 rows x 11 columns]

# %%
data = pd.DataFrame()
for file in all_filenames:
    
    df = run(file)
    data = pd.concat([data, df])

data
# Out:
#              corpus      doc_id sent_id eg_id                           index  \
# 0     semeval2010t8  train.json       0     0    semeval2010t8_train.json_0_0
# 1     semeval2010t8  train.json       1     0    semeval2010t8_train.json_1_0
# 2     semeval2010t8  train.json       2     0    semeval2010t8_train.json_2_0
# 3     semeval2010t8  train.json       3     0    semeval2010t8_train.json_3_0
# 4     semeval2010t8  train.json       4     0    semeval2010t8_train.json_4_0
# ...             ...         ...     ...   ...                             ...
# 2712  semeval2010t8   test.json    2710     0  semeval2010t8_test.json_2710_0
# 2713  semeval2010t8   test.json    2711     0  semeval2010t8_test.json_2711_0
# 2714  semeval2010t8   test.json    2712     0  semeval2010t8_test.json_2712_0
# 2715  semeval2010t8   test.json    2713     0  semeval2010t8_test.json_2713_0
# 2716  semeval2010t8   test.json    2714     0  semeval2010t8_test.json_2714_0
#
#                                                    text  \
# 0     The system as described above has its greatest...
# 1     The child was carefully wrapped and bound into...
# 2     The author of a keygen uses a disassembler to ...
# 3                A misty ridge uprises from the surge .
# 4     The student association is the voice of the un...
# ...                                                 ...
# 2712  After seating all the idols , which itself tak...
# 2713  The minister attributed the slow production of...
# 2714  The umbrella frame is provided with a movable ...
# 2715  Manos: The Hands of Fate is a low-budget horro...
# 2716  A few days before the service , Tom Burris had...
#
#                                            text_w_pairs  seq_label  \
# 0     The system as described above has its greatest...          0
# 1     The <ARG1>child</ARG1> was carefully wrapped a...          0
# 2     The <ARG1>author</ARG1> of a keygen uses a <AR...          0
# 3     A misty <ARG1>ridge</ARG1> uprises from the <A...          0
# 4     The <ARG0>student</ARG0> <ARG1>association</AR...          0
# ...                                                 ...        ...
# 2712  After seating all the idols , which itself tak...          0
# 2713  The minister attributed the slow production of...          0
# 2714  The <ARG1>umbrella</ARG1> <ARG0>frame</ARG0> i...          0
# 2715  Manos: The Hands of Fate is a low-budget horro...          0
# 2716  A few days before the service , Tom Burris had...          0
#
#       pair_label context  num_sents
# 0              0                  1
# 1              0                  1
# 2              0                  1
# 3              0                  1
# 4              0                  1
# ...          ...     ...        ...
# 2712           0                  1
# 2713           0                  1
# 2714           0                  1
# 2715           0                  1
# 2716           0                  1
#
# [10717 rows x 11 columns]

# %%
from collections import Counter

print('All Examples')
print('Seq Level:', Counter(data['seq_label'])) # if sentence level causality exists
print('Pair Level:',Counter(data['pair_label'])) # if ARG0-ARG1 pair level causality exists
print('Seq Level (Unique):',Counter(data.drop_duplicates(subset=['corpus','doc_id','sent_id'])['seq_label']))

print('\nSingle Sentence Examples')
print('Seq Level:', Counter(data.loc[data['num_sents']==1,'seq_label'])) # if sentence level causality exists
print('Pair Level:', Counter(data.loc[data['num_sents']==1,'pair_label'])) # if ARG0-ARG1 pair level causality exists
print('Seq Level (Unique):',Counter(data.loc[data['num_sents']==1].drop_duplicates(subset=['corpus','doc_id','sent_id'])['seq_label']))
# Out:
# All Examples
# Seq Level: Counter({0: 9386, 1: 1331})
# Pair Level: Counter({0: 9386, 1: 1331})
# Seq Level (Unique): Counter({0: 9363, 1: 1327})
#
# Single Sentence Examples
# Seq Level: Counter({0: 9386, 1: 1331})
# Pair Level: Counter({0: 9386, 1: 1331})
# Seq Level (Unique): Counter({0: 9363, 1: 1327})

# %%
data.to_csv('cleaned/semeval2010t8.csv', index=False,encoding='utf-8-sig')
